# %%
#importing the Libraries#
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Reading the Dataset#
dataset=pd.read_csv('insurance_pre.csv')

# %%
#what saved in this file#
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#create dummy data set. #drop a column#
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
#what saved in this file#
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
#catogorical data convert to numerical data#
dataset=dataset.astype(int)

# %%
#what saved in this file#
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
#show all columns in dataset#
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
#independent variable means input.  #split input variables. #dataset assigned to independent variable#
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
#what saved in this file#
independent
# Out:
#       age  bmi  children  sex_male  smoker_yes
# 0      19   27         0         0           1
# 1      18   33         1         1           0
# 2      28   33         3         1           0
# 3      33   22         0         1           0
# 4      32   28         0         1           0
# ...   ...  ...       ...       ...         ...
# 1333   50   30         3         1           0
# 1334   18   31         0         0           0
# 1335   18   36         0         0           0
# 1336   21   25         0         0           0
# 1337   61   29         0         0           1
#
# [1338 rows x 5 columns]

# %%
#dependent variable means output.  #split output variables. #dataset assigned to dependent variable#
dependent=dataset[['charges']]

# %%
#what saved in this file#
dependent
# Out:
#       charges
# 0       16884
# 1        1725
# 2        4449
# 3       21984
# 4        3866
# ...       ...
# 1333    10600
# 1334     2205
# 1335     1629
# 1336     2007
# 1337    29141
#
# [1338 rows x 1 columns]

# %%
#machine learning algorithms provider is sklearn #split train set and test set#
from sklearn.model_selection import train_test_split 
X_train,X_test,y_train,y_test=train_test_split(independent, dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Model creation#
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','poly','sigmoid','linear'],
              'C':[19,100,1000,2000,3000],'gamma':['auto','scale']}

grid=GridSearchCV(SVR(), param_grid, refit=True, verbose=3,n_jobs=-1)

#fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\Users\anandha rishi\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [19, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
#Print best parameter afterr tuning#
#Print(grid.best_params_)
re=grid.cv_results_

print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.103132      0.007655         0.046876    9.883400e-03      19
# 1        0.093841      0.009709         0.016475    1.692560e-03      19
# 2        0.112507      0.006251         0.018752    6.251789e-03      19
# 3        0.091881      0.012964         0.015711    1.788920e-04      19
# 4        0.098739      0.006427         0.045970    2.876276e-03      19
# 5        0.075004      0.006249         0.015629    2.347666e-06      19
# 6        0.109380      0.000004         0.018752    6.251026e-03      19
# 7        0.103700      0.025026         0.012590    6.297480e-03      19
# 8        0.098840      0.006505         0.043753    6.251836e-03     100
# 9        0.096122      0.002899         0.015632    2.971732e-06     100
# 10       0.117457      0.014277         0.024244    1.120017e-02     100
# 11       0.090807      0.011506         0.018754    6.249190e-03     100
# 12       0.096882      0.006248         0.037501    7.656136e-03     100
# 13       0.087507      0.007658         0.012503    6.251502e-03     100
# 14       0.118140      0.011812         0.021878    7.656369e-03     100
# 15       0.090627      0.006253         0.018757    6.249213e-03     100
# 16       0.126844      0.009355         0.040628    7.658666e-03    1000
# 17       0.123172      0.003671         0.015626    2.981662e-06    1000
# 18       0.121880      0.011693         0.021880    7.655259e-03    1000
# 19       0.118703      0.007347         0.013573    7.095509e-03    1000
# 20       0.115635      0.007658         0.046875    3.367024e-06    1000
# 21       0.151054      0.041164         0.020583    7.614502e-03    1000
# 22       0.123569      0.007810         0.018747    6.248641e-03    1000
# 23       0.118755      0.012504         0.015631    8.313940e-07    1000
# 24       0.127377      0.005729         0.037501    7.653488e-03    2000
# 25       0.203134      0.029648         0.015632    2.896565e-06    2000
# 26       0.126207      0.015724         0.023032    7.037536e-03    2000
# 27       0.143757      0.006247         0.015628    4.726705e-06    2000
# 28       0.140624      0.013972         0.037503    7.656254e-03    2000
# 29       0.228132      0.043755         0.012503    6.251693e-03    2000
# 30       0.124965      0.009819         0.025793    8.423472e-03    2000
# 31       0.150653      0.006937         0.012502    6.251145e-03    2000
# 32       0.109382      0.000002         0.031251    8.714517e-07    3000
# 33       0.214571      0.066449         0.009569    7.820909e-03    3000
# 34       0.096880      0.006254         0.015628    2.791025e-06    3000
# 35       0.146261      0.021440         0.013132    6.677961e-03    3000
# 36       0.134384      0.007654         0.040626    7.654402e-03    3000
# 37       0.268831      0.057211         0.013306    6.832133e-03    3000
# 38       0.121882      0.011693         0.025002    7.656291e-03    3000
# 39       0.162487      0.007437         0.009616    5.793322e-03    3000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto         poly
# 2         auto      sigmoid
# 3         auto       linear
# 4        scale          rbf
# 5        scale         poly
# 6        scale      sigmoid
# 7        scale       linear
# 8         auto          rbf
# 9         auto         poly
# 10        auto      sigmoid
# 11        auto       linear
# 12       scale          rbf
# 13       scale         poly
# 14       scale      sigmoid
# 15       scale       linear
# 16        auto          rbf
# 17        auto         poly
# 18        auto      sigmoid
# 19        auto       linear
# 20       scale          rbf
# 21       scale         poly
# 22       scale      sigmoid
# 23       scale       linear
# 24        auto          rbf
# 25        auto         poly
# 26        auto      sigmoid
# 27        auto       linear
# 28       scale          rbf
# 29       scale         poly
# 30       scale      sigmoid
# 31       scale       linear
# 32        auto          rbf
# 33        auto         poly
# 34        auto      sigmoid
# 35        auto       linear
# 36       scale          rbf
# 37       scale         poly
# 38       scale      sigmoid
# 39       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 19, 'gamma': 'auto', 'kernel': 'rbf'}           0.041760
# 1        {'C': 19, 'gamma': 'auto', 'kernel': 'poly'}           0.135846
# 2     {'C': 19, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.121028
# 3      {'C': 19, 'gamma': 'auto', 'kernel': 'linear'}           0.501872
# 4        {'C': 19, 'gamma': 'scale', 'kernel': 'rbf'}           0.041891
# 5       {'C': 19, 'gamma': 'scale', 'kernel': 'poly'}           0.133545
# 6    {'C': 19, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.120615
# 7     {'C': 19, 'gamma': 'scale', 'kernel': 'linear'}           0.501872
# 8        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.300124
# 9       {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.537814
# 10   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.482712
# 11    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.584840
# 12      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.300606
# 13     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.534189
# 14  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.481175
# 15   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.584840
# 16      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.731988
# 17     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.830806
# 18  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.323851
# 19   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.604973
# 20     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.732239
# 21    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.829390
# 22  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.328341
# 23  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.604973
# 24      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.816190
# 25     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.847468
# 26  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.445302
# 27   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.605615
# 28     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.816457
# 29    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.847539
# 30  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -0.616220
# 31  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.605615
# 32      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.829220
# 33     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.850124
# 34  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -1.754076
# 35   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.657721
# 36     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.829352
# 37    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.850157
# 38  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...          -1.682090
# 39  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.657721
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.056597          -0.068119          -0.055732
# 1            0.156542           0.042279           0.069698
# 2            0.168408           0.025820           0.038136
# 3            0.589715           0.455488           0.487265
# 4            0.056394          -0.068008          -0.055826
# 5            0.159592           0.040591           0.071176
# 6            0.169263           0.025516           0.038364
# 7            0.589715           0.455488           0.487265
# 8            0.339544           0.174257           0.217017
# 9            0.574688           0.470001           0.532987
# 10           0.560842           0.433137           0.449720
# 11           0.656088           0.553185           0.577115
# 12           0.338790           0.174699           0.216705
# 13           0.579262           0.467718           0.534956
# 14           0.561849           0.429295           0.451834
# 15           0.656088           0.553185           0.577115
# 16           0.743653           0.686787           0.715193
# 17           0.806043           0.799112           0.802509
# 18           0.371445           0.287282           0.286805
# 19           0.589001           0.623195           0.538195
# 20           0.743319           0.687028           0.715059
# 21           0.805648           0.798663           0.802669
# 22           0.386884           0.216176           0.287478
# 23           0.589001           0.623195           0.538195
# 24           0.779806           0.791733           0.791076
# 25           0.808587           0.813767           0.803786
# 26          -0.511012          -0.493784          -0.461297
# 27           0.583248           0.697406           0.532387
# 28           0.779685           0.791839           0.790950
# 29           0.808183           0.813734           0.803711
# 30          -0.532822          -0.478194          -0.542484
# 31           0.583248           0.697406           0.532387
# 32           0.791264           0.810701           0.809750
# 33           0.806758           0.814590           0.804422
# 34          -2.044957          -1.699509          -1.914567
# 35           0.583243           0.697893           0.529476
# 36           0.791147           0.810772           0.809730
# 37           0.806802           0.814553           0.804154
# 38          -1.830750          -1.676185          -1.941103
# 39           0.583243           0.697893           0.529476
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.070211        -0.019141        0.056198               35
# 1            0.031337         0.087140        0.050239               32
# 2            0.033332         0.077345        0.057149               34
# 3            0.459818         0.498832        0.048587               23
# 4           -0.070213        -0.019152        0.056165               36
# 5            0.031361         0.087253        0.050864               31
# 6            0.033337         0.077419        0.057382               33
# 7            0.459818         0.498832        0.048587               23
# 8            0.183337         0.242856        0.065642               29
# 9            0.425034         0.508105        0.053456               22
# 10           0.431324         0.471547        0.048307               25
# 11           0.547448         0.583735        0.038807               19
# 12           0.183330         0.242826        0.065439               30
# 13           0.425072         0.508240        0.054754               21
# 14           0.431336         0.471098        0.049065               26
# 15           0.547448         0.583735        0.038807               19
# 16           0.644532         0.704430        0.035532               12
# 17           0.739945         0.795683        0.030020                7
# 18           0.351347         0.324146        0.033854               27
# 19           0.617342         0.594541        0.030513               17
# 20           0.644529         0.704435        0.035467               11
# 21           0.739952         0.795264        0.029659                8
# 22           0.351327         0.314041        0.058624               28
# 23           0.617342         0.594541        0.030513               17
# 24           0.732585         0.782278        0.027540               10
# 25           0.755123         0.805746        0.029596                3
# 26          -0.099723        -0.402223        0.153017               37
# 27           0.681584         0.620048        0.061673               15
# 28           0.732583         0.782303        0.027609                9
# 29           0.755123         0.805658        0.029608                4
# 30          -0.102534        -0.454451        0.181367               38
# 31           0.681584         0.620048        0.061673               15
# 32           0.742128         0.796613        0.029771                6
# 33           0.757864         0.806752        0.029455                1
# 34          -1.035870        -1.689796        0.348857               40
# 35           0.655869         0.624840        0.060341               13
# 36           0.742127         0.796625        0.029809                5
# 37           0.757866         0.806706        0.029467                2
# 38          -1.036223        -1.633270        0.314468               39
# 39           0.655869         0.624840        0.060341               13

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("children:"))
sex_male_input=int(input("sex Male 0 or 1:"))
smoker_yes_input=int(input("smoker yes 0 or 1:"))
# Out:
# Age: 32
# BMI: 43
# children: 2
# sex Male 0 or 1: 0
# smoker yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[2457066.3958234]
