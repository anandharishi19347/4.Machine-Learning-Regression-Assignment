# %%
#importing the Libraries#
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Reading the Dataset#
dataset=pd.read_csv('insurance_pre.csv')

# %%
#what saved in this file#
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#create dummy data set. #drop a column#
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
#what saved in this file#
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
#catogorical data convert to numerical data#
dataset=dataset.astype(int)

# %%
#what saved in this file#
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
#show all columns in dataset#
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
#independent variable means input.  #split input variables. #dataset assigned to independent variable#
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
#what saved in this file#
independent
# Out:
#       age  bmi  children  sex_male  smoker_yes
# 0      19   27         0         0           1
# 1      18   33         1         1           0
# 2      28   33         3         1           0
# 3      33   22         0         1           0
# 4      32   28         0         1           0
# ...   ...  ...       ...       ...         ...
# 1333   50   30         3         1           0
# 1334   18   31         0         0           0
# 1335   18   36         0         0           0
# 1336   21   25         0         0           0
# 1337   61   29         0         0           1
#
# [1338 rows x 5 columns]

# %%
#dependent variable means output.  #split output variables. #dataset assigned to dependent variable#
dependent=dataset[['charges']]

# %%
#what saved in this file#
dependent
# Out:
#       charges
# 0       16884
# 1        1725
# 2        4449
# 3       21984
# 4        3866
# ...       ...
# 1333    10600
# 1334     2205
# 1335     1629
# 1336     2007
# 1337    29141
#
# [1338 rows x 1 columns]

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
#Model creation#
from sklearn.model_selection import GridSearchCV
param_grid = {'loss':['squared_error','absolute_error','huber','quantile'],
              'max_features':[10,100,1000,2000,3000],'criterion':['friedman_mse','squared_error']}

grid=GridSearchCV(GradientBoostingRegressor(), param_grid, refit=True, verbose=3,n_jobs=-1)

#fitting the model for grid search
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\Users\anandha rishi\anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=GradientBoostingRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['friedman_mse', 'squared_error'],
#                          'loss': ['squared_error', 'absolute_error', 'huber',
#                                   'quantile'],
#                          'max_features': [10, 100, 1000, 2000, 3000]},
#              verbose=3)

# %%
#Print best parameter afterr tuning#
#Print(grid.best_params_)

re=grid.cv_results_

print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'friedman_mse', 'loss': 'squared_error', 'max_features': 100}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.289973      0.024010         0.011062        0.006193
# 1        0.255892      0.007592         0.009377        0.007656
# 2        0.253144      0.006250         0.009376        0.007656
# 3        0.280402      0.027702         0.003127        0.006253
# 4        0.260679      0.005961         0.003612        0.006081
# 5        0.703223      0.021854         0.006250        0.007655
# 6        0.584746      0.049068         0.007736        0.009761
# 7        0.553896      0.004338         0.000000        0.000000
# 8        0.577906      0.012037         0.006250        0.007655
# 9        0.608806      0.047397         0.003125        0.006250
# 10       0.828469      0.028500         0.003125        0.006250
# 11       0.800801      0.006465         0.009376        0.007655
# 12       0.822154      0.020288         0.003125        0.006251
# 13       0.729671      0.009917         0.006254        0.007660
# 14       0.721180      0.020226         0.003125        0.006251
# 15       0.539837      0.037287         0.009375        0.007655
# 16       0.590727      0.038090         0.006938        0.008566
# 17       0.624476      0.016405         0.009375        0.007655
# 18       0.633228      0.046026         0.004806        0.006313
# 19       0.611900      0.028199         0.006250        0.007655
# 20       0.234373      0.000028         0.012500        0.006250
# 21       0.241112      0.009599         0.003125        0.006250
# 22       0.236229      0.002247         0.006250        0.007655
# 23       0.234373      0.000034         0.009376        0.007655
# 24       0.236848      0.014793         0.009376        0.007656
# 25       0.603204      0.042058         0.009374        0.007654
# 26       0.542153      0.009093         0.007160        0.008886
# 27       0.565953      0.034624         0.012500        0.006250
# 28       0.646782      0.008759         0.007782        0.006988
# 29       0.646954      0.015349         0.003469        0.006115
# 30       0.800645      0.006244         0.006251        0.007655
# 31       0.805473      0.015847         0.006250        0.007655
# 32       0.736713      0.024826         0.006250        0.007655
# 33       0.746696      0.015994         0.006250        0.007655
# 34       0.797250      0.083469         0.011748        0.006052
# 35       0.993031      0.092685         0.043991        0.057493
# 36       0.899168      0.096575         0.009487        0.002698
# 37       0.853870      0.157242         0.009036        0.012314
# 38       0.990989      0.052428         0.005530        0.006868
# 39       0.915394      0.103787         0.009378        0.007657
#
#    param_criterion      param_loss param_max_features  \
# 0     friedman_mse   squared_error                 10
# 1     friedman_mse   squared_error                100
# 2     friedman_mse   squared_error               1000
# 3     friedman_mse   squared_error               2000
# 4     friedman_mse   squared_error               3000
# 5     friedman_mse  absolute_error                 10
# 6     friedman_mse  absolute_error                100
# 7     friedman_mse  absolute_error               1000
# 8     friedman_mse  absolute_error               2000
# 9     friedman_mse  absolute_error               3000
# 10    friedman_mse           huber                 10
# 11    friedman_mse           huber                100
# 12    friedman_mse           huber               1000
# 13    friedman_mse           huber               2000
# 14    friedman_mse           huber               3000
# 15    friedman_mse        quantile                 10
# 16    friedman_mse        quantile                100
# 17    friedman_mse        quantile               1000
# 18    friedman_mse        quantile               2000
# 19    friedman_mse        quantile               3000
# 20   squared_error   squared_error                 10
# 21   squared_error   squared_error                100
# 22   squared_error   squared_error               1000
# 23   squared_error   squared_error               2000
# 24   squared_error   squared_error               3000
# 25   squared_error  absolute_error                 10
# 26   squared_error  absolute_error                100
# 27   squared_error  absolute_error               1000
# 28   squared_error  absolute_error               2000
# 29   squared_error  absolute_error               3000
# 30   squared_error           huber                 10
# 31   squared_error           huber                100
# 32   squared_error           huber               1000
# 33   squared_error           huber               2000
# 34   squared_error           huber               3000
# 35   squared_error        quantile                 10
# 36   squared_error        quantile                100
# 37   squared_error        quantile               1000
# 38   squared_error        quantile               2000
# 39   squared_error        quantile               3000
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'friedman_mse', 'loss': 'squared...           0.878293
# 1   {'criterion': 'friedman_mse', 'loss': 'squared...           0.878298
# 2   {'criterion': 'friedman_mse', 'loss': 'squared...           0.878300
# 3   {'criterion': 'friedman_mse', 'loss': 'squared...           0.878289
# 4   {'criterion': 'friedman_mse', 'loss': 'squared...           0.878238
# 5   {'criterion': 'friedman_mse', 'loss': 'absolut...           0.818608
# 6   {'criterion': 'friedman_mse', 'loss': 'absolut...           0.876159
# 7   {'criterion': 'friedman_mse', 'loss': 'absolut...           0.853546
# 8   {'criterion': 'friedman_mse', 'loss': 'absolut...           0.875958
# 9   {'criterion': 'friedman_mse', 'loss': 'absolut...           0.855299
# 10  {'criterion': 'friedman_mse', 'loss': 'huber',...           0.888884
# 11  {'criterion': 'friedman_mse', 'loss': 'huber',...           0.888891
# 12  {'criterion': 'friedman_mse', 'loss': 'huber',...           0.888875
# 13  {'criterion': 'friedman_mse', 'loss': 'huber',...           0.888875
# 14  {'criterion': 'friedman_mse', 'loss': 'huber',...           0.888842
# 15  {'criterion': 'friedman_mse', 'loss': 'quantil...           0.528713
# 16  {'criterion': 'friedman_mse', 'loss': 'quantil...           0.528738
# 17  {'criterion': 'friedman_mse', 'loss': 'quantil...           0.528754
# 18  {'criterion': 'friedman_mse', 'loss': 'quantil...           0.528714
# 19  {'criterion': 'friedman_mse', 'loss': 'quantil...           0.528773
# 20  {'criterion': 'squared_error', 'loss': 'square...           0.878340
# 21  {'criterion': 'squared_error', 'loss': 'square...           0.878293
# 22  {'criterion': 'squared_error', 'loss': 'square...           0.878384
# 23  {'criterion': 'squared_error', 'loss': 'square...           0.878202
# 24  {'criterion': 'squared_error', 'loss': 'square...           0.878289
# 25  {'criterion': 'squared_error', 'loss': 'absolu...           0.867413
# 26  {'criterion': 'squared_error', 'loss': 'absolu...           0.850215
# 27  {'criterion': 'squared_error', 'loss': 'absolu...           0.850211
# 28  {'criterion': 'squared_error', 'loss': 'absolu...           0.843789
# 29  {'criterion': 'squared_error', 'loss': 'absolu...           0.861336
# 30  {'criterion': 'squared_error', 'loss': 'huber'...           0.888865
# 31  {'criterion': 'squared_error', 'loss': 'huber'...           0.888889
# 32  {'criterion': 'squared_error', 'loss': 'huber'...           0.888850
# 33  {'criterion': 'squared_error', 'loss': 'huber'...           0.888885
# 34  {'criterion': 'squared_error', 'loss': 'huber'...           0.888831
# 35  {'criterion': 'squared_error', 'loss': 'quanti...           0.528795
# 36  {'criterion': 'squared_error', 'loss': 'quanti...           0.528736
# 37  {'criterion': 'squared_error', 'loss': 'quanti...           0.528755
# 38  {'criterion': 'squared_error', 'loss': 'quanti...           0.528747
# 39  {'criterion': 'squared_error', 'loss': 'quanti...           0.528729
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.796756           0.892461           0.846087
# 1            0.796743           0.892461           0.846455
# 2            0.796758           0.892370           0.846087
# 3            0.796758           0.892370           0.846262
# 4            0.796756           0.892370           0.846285
# 5            0.758927           0.866324           0.828060
# 6            0.757584           0.873087           0.829249
# 7            0.761273           0.869389           0.831682
# 8            0.760805           0.862767           0.832988
# 9            0.761273           0.859531           0.829249
# 10           0.788803           0.885819           0.843083
# 11           0.788803           0.885645           0.843503
# 12           0.788414           0.885654           0.843506
# 13           0.788705           0.886178           0.843505
# 14           0.788072           0.886528           0.843431
# 15           0.648252           0.641568           0.663994
# 16           0.686747           0.641596           0.669992
# 17           0.653945           0.641568           0.659759
# 18           0.661586           0.641438           0.660572
# 19           0.686747           0.641551           0.653104
# 20           0.796758           0.892370           0.846285
# 21           0.796743           0.892461           0.846285
# 22           0.796743           0.892370           0.846285
# 23           0.796756           0.892370           0.846262
# 24           0.796758           0.892461           0.846262
# 25           0.760979           0.862024           0.832870
# 26           0.758969           0.862210           0.831152
# 27           0.758927           0.859531           0.829249
# 28           0.760538           0.870094           0.831026
# 29           0.769648           0.862210           0.830750
# 30           0.788688           0.885692           0.843508
# 31           0.788501           0.886198           0.843107
# 32           0.788803           0.886450           0.843511
# 33           0.788292           0.886101           0.843440
# 34           0.788705           0.886475           0.843322
# 35           0.645968           0.642042           0.654082
# 36           0.653006           0.642240           0.659008
# 37           0.643152           0.637141           0.662279
# 38           0.675743           0.636166           0.661758
# 39           0.656522           0.637001           0.666304
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.861403         0.855000        0.033042                9
# 1            0.861547         0.855101        0.033033                1
# 2            0.861418         0.854987        0.033022               10
# 3            0.861540         0.855044        0.033016                6
# 4            0.861604         0.855051        0.033010                5
# 5            0.854891         0.825362        0.037460               30
# 6            0.853913         0.837999        0.043552               21
# 7            0.854891         0.834156        0.038380               25
# 8            0.854615         0.837427        0.040775               22
# 9            0.853914         0.831853        0.036853               26
# 10           0.864716         0.854261        0.036643               19
# 11           0.864716         0.854312        0.036590               15
# 12           0.864716         0.854233        0.036728               20
# 13           0.864716         0.854396        0.036713               13
# 14           0.864716         0.854318        0.036999               14
# 15           0.680458         0.632597        0.053654               38
# 16           0.680458         0.641507        0.058467               31
# 17           0.680458         0.632897        0.053568               36
# 18           0.680458         0.634554        0.054341               34
# 19           0.680458         0.638127        0.057184               32
# 20           0.861435         0.855038        0.033018                7
# 21           0.861555         0.855067        0.033042                3
# 22           0.861548         0.855066        0.033034                4
# 23           0.861547         0.855027        0.033004                8
# 24           0.861596         0.855073        0.033038                2
# 25           0.854276         0.835512        0.039076               23
# 26           0.852923         0.831094        0.037449               27
# 27           0.847996         0.829183        0.036478               29
# 28           0.847996         0.830689        0.037270               28
# 29           0.847411         0.834271        0.034276               24
# 30           0.864716         0.854294        0.036633               16
# 31           0.864716         0.854282        0.036816               18
# 32           0.864716         0.854466        0.036721               11
# 33           0.864716         0.854287        0.036854               17
# 34           0.864716         0.854410        0.036768               12
# 35           0.680458         0.630269        0.052475               40
# 36           0.680458         0.632690        0.053451               37
# 37           0.680458         0.630357        0.053032               39
# 38           0.680458         0.636574        0.056074               33
# 39           0.680458         0.633803        0.054406               35

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("children:"))
sex_male_input=int(input("sex Male 0 or 1:"))
smoker_yes_input=int(input("smoker yes 0 or 1:"))
# Out:
# Age: 32
# BMI: 43
# children: 2
# sex Male 0 or 1: 0
# smoker yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[43029.49849958]
# C:\Users\anandha rishi\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
